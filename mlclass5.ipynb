# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Akash Raj\\Downloads\\battery_charger.csv')
df
# Out:
#     inp1  inp2   out
# 0    0.0   0.0  4.00
# 1   30.0   1.0  4.00
# 2   37.0   0.2  4.00
# 3   40.0   0.0  3.00
# 4   40.0   1.0  2.00
# 5   41.0   0.5  2.00
# 6   42.0   1.0  1.00
# 7   43.0   0.5  1.00
# 8   43.0   1.0  1.00
# 9   44.0   0.0  0.10
# 10  44.0   0.4  0.10
# 11  45.0   0.1  0.10
# 12  45.0   0.5  0.10
# 13  50.0   1.0  0.10
# 14  37.0   0.5  3.90
# 15  45.0   0.5  0.09
# 16  45.0   0.1  0.09
# 17  45.0   0.7  0.09
# 18  25.0   1.0  4.00
# 19   1.0   1.0  4.00
# 20   1.0   0.5  4.00
# 21   0.0   0.5  4.00
# 22   4.0   0.5  4.00
# 23   4.0   0.0  4.00
# 24   4.0   1.0  4.00
# 25   8.0   1.0  4.00
# 26   8.0   0.0  4.10
# 27   5.0   1.0  4.00
# 28   2.0   1.0  4.00
# 29  12.0   0.2  4.00
# 30  12.0   0.9  3.90
# 31  15.4   0.8  4.00
# 32  16.8   0.9  4.00
# 33  21.0   0.1  4.00
# 34  28.0   0.1  4.00
# 35  50.0   0.1  0.09
# 36  49.1   0.1  0.09
# 37  47.0   0.1  0.09
# 38  41.2   0.7  1.51
# 39  41.5   0.0  1.90

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm
# Out:
# LinearRegression()

# %%
x=df[['inp1','inp2']]
y=df['out']

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
z=lm.predict(x)
z
# Out:
# array([4.66504615, 2.3219338 , 1.68785361, 1.42818154, 1.51271764,
#        1.38952798, 1.35087441, 1.22768475, 1.2699528 , 1.10449508,
#        1.13830952, 1.03202708, 1.06584152, 0.70350149, 1.71321444,
#        1.06584152, 1.03202708, 1.08274874, 2.72654187, 4.66866064,
#        4.62639259, 4.7073142 , 4.38362774, 4.34135969, 4.42589579,
#        4.10220933, 4.01767323, 4.34497418, 4.58773902, 3.71089399,
#        3.77006926, 3.48648216, 3.38164551, 2.97414584, 2.40769453,
#        0.627419  , 0.70024845, 0.87018385, 1.39025088, 1.30679912])

# %%
a=lm.predict([[60,1]])
a
# Out:
# c:\Users\Akash Raj\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-0.10571466])
