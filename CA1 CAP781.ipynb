# %% [markdown]
# <h1> Set A

# %% [markdown]
# <i><h2> Import of iris data and count number of rows and columns in the given dataset

# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\Akash Raj\\Downloads\iriss.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# <p> Number of rows = 150, number of columns = 5

# %% [markdown]
# <h2><i> Check if null values exists or not

# %%
df.isnull().value_counts()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# False         False        False         False        False      150
# dtype: int64

# %% [markdown]
# <i><h2> Count number of values

# %%
df['species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %% [markdown]
# <p> Number of values belong to Catagory 0 is 50 and Catagory 1 is 50

# %% [markdown]
# <i> <h2> Find correlation with the output

# %%
cor=df.corr()
cor_target = abs(cor["species"])
cor_target
# Out:
# sepal_length    0.782561
# sepal_width     0.419446
# petal_length    0.949043
# petal_width     0.956464
# species         1.000000
# Name: species, dtype: float64

# %% [markdown]
# <p> According to the corr output two highly correlated columns are 'petal_length' and 'petal_width'

# %% [markdown]
# <i><h2> China GDP dataset

# %%
import pandas as pd
china_dataset = pd.read_csv('C:\\Users\\Akash Raj\\Downloads\china_gdp.csv')
china_dataset
# Out:
#     Year         Value
# 0   1960  5.918412e+10
# 1   1961  4.955705e+10
# 2   1962  4.668518e+10
# 3   1963  5.009730e+10
# 4   1964  5.906225e+10
# 5   1965  6.970915e+10
# 6   1966  7.587943e+10
# 7   1967  7.205703e+10
# 8   1968  6.999350e+10
# 9   1969  7.871882e+10
# 10  1970  9.150621e+10
# 11  1971  9.856202e+10
# 12  1972  1.121598e+11
# 13  1973  1.367699e+11
# 14  1974  1.422547e+11
# 15  1975  1.611625e+11
# 16  1976  1.516277e+11
# 17  1977  1.723490e+11
# 18  1978  1.483821e+11
# 19  1979  1.768565e+11
# 20  1980  1.896500e+11
# 21  1981  1.943690e+11
# 22  1982  2.035496e+11
# 23  1983  2.289502e+11
# 24  1984  2.580821e+11
# 25  1985  3.074796e+11
# 26  1986  2.988058e+11
# 27  1987  2.713498e+11
# 28  1988  3.107222e+11
# 29  1989  3.459575e+11
# 30  1990  3.589732e+11
# 31  1991  3.814547e+11
# 32  1992  4.249341e+11
# 33  1993  4.428746e+11
# 34  1994  5.622611e+11
# 35  1995  7.320320e+11
# 36  1996  8.608441e+11
# 37  1997  9.581594e+11
# 38  1998  1.025277e+12
# ...

# %% [markdown]
# <h2> Scatter Graph of CHina GDP

# %%
import matplotlib.pyplot as plt
plt.scatter(china_dataset['Year'],china_dataset['Value'])
plt.xlabel('Year')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# <p> According to the graph we can observe that the graph is not linear because for linear data we need a dependent and an independent variable. And according to the curve also it doesnot seem linear.
