# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
patient_profiles = pd.read_csv("C:/Users/Akash Raj/Downloads/data/Patient_Profile.csv")
First_Health_Camp_Attended = pd.read_csv("C:/Users/Akash Raj/Downloads/data/First_Health_Camp_Attended.csv")
Second_Health_Camp_Attended = pd.read_csv("C:/Users/Akash Raj/Downloads/data/Second_Health_Camp_Attended.csv")
Third_Health_Camp_Attended = pd.read_csv("C:/Users/Akash Raj/Downloads/data/Third_Health_Camp_Attended.csv")
Health_Camp_Detail = pd.read_csv("C:/Users/Akash Raj/Downloads/data/Health_Camp_Detail.csv")
Train = pd.read_csv("C:/Users/Akash Raj/Downloads/data/Train.csv")

# %%
patient_profiles
# Out:
#        Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0          516956                0                0               0
# 1          507733                0                0               0
# 2          508307                0                0               0
# 3          512612                0                0               0
# 4          521075                0                0               0
# ...           ...              ...              ...             ...
# 37628      518600                0                0               0
# 37629      509515                0                0               0
# 37630      510713                0                0               0
# 37631      493667                0                0               0
# 37632      498051                0                0               0
#
#        Facebook_Shared Income Education_Score   Age First_Interaction  \
# 0                    0      1              90    39         18-Jun-03
# ...

# %%
d_patient_profiles = pd.DataFrame(patient_profiles['Age'].replace('None',0).astype('int64'))
dd = d_patient_profiles.loc[:,'Age'].sort_values()
dd
# Out:
# 18816     0
# 23934     0
# 23932     0
# 23931     0
# 23930     0
#          ..
# 27367    78
# 31589    78
# 32682    78
# 27995    78
# 4        80
# Name: Age, Length: 37633, dtype: int64

# %%
l1=0
l2=0
l3=0
l4=0


for i in dd:
    if i > 1 and i <= 40:
        l1+=1
    if i > 40 and i <=70:
        l2+=1
    if i>70:
        l3+=1
    if i ==0:
        l4+=1

age_group = [l1,l2,l3,l4]
age_label = ['1 to 40','41 to 70','Older than 70','People whose age is not Specified']
expl=[0.1,0.2,0.3,0]

cols=['r','orange','g','c']
plt.figure(figsize=(10,8))
plt.pie(age_group, labels= age_label, colors=cols,startangle=0,explode=expl,shadow=True,autopct='%1.0f%%')
plt.legend(title="Age group",loc='lower left')
plt.title(label='Age group of people who got Interacted with Health Camps', fontsize = 20)
plt.show()

# %%
online_followers = pd.DataFrame(patient_profiles['Online_Follower'])
of = online_followers.loc[:,'Online_Follower']
of
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37628    0
# 37629    0
# 37630    0
# 37631    0
# 37632    0
# Name: Online_Follower, Length: 37633, dtype: int64

# %%
fb_shares = pd.DataFrame(patient_profiles['Facebook_Shared'])
ff = fb_shares.loc[:,'Facebook_Shared']
ff
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37628    0
# 37629    0
# 37630    0
# 37631    0
# 37632    0
# Name: Facebook_Shared, Length: 37633, dtype: int64

# %%
lkdn_followers = pd.DataFrame(patient_profiles['LinkedIn_Shared'])
ls = lkdn_followers.loc[:,'LinkedIn_Shared']
ls
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37628    0
# 37629    0
# 37630    0
# 37631    0
# 37632    0
# Name: LinkedIn_Shared, Length: 37633, dtype: int64

# %%
tw_followers = pd.DataFrame(patient_profiles['Twitter_Shared'])
ts = tw_followers.loc[:,'Twitter_Shared']
ts
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37628    0
# 37629    0
# 37630    0
# 37631    0
# 37632    0
# Name: Twitter_Shared, Length: 37633, dtype: int64

# %%
plt.figure(figsize=(16,10))

plt.subplot(2,2,1)
plt.title("Age Group vs Online Followers")
plt.xlabel('Age')
plt.ylabel('Online Followers')
plt.plot(dd,of,'*')


plt.subplot(2,2,2)
plt.title("Age Group vs Facebook Shares")
plt.xlabel('Age')
plt.ylabel('Facebook Share')
plt.plot(dd,ff,'*')

plt.subplot(2,2,3)
plt.title("Age Group vs LinkedIn Shares")
plt.xlabel('Age')
plt.ylabel('LinkedIn Share')
plt.plot(dd,ls,'D')


plt.subplot(2,2,4)
plt.xlabel('Age')
plt.ylabel('Twitter Share')
plt.plot(dd,ts,'s')
plt.title("Age Group vs Twitter Shares")
plt.show()

# 0 denotes for the data which is Not Available 'None'

# %% [markdown]
# **Details of Age group sharing update about Health Camp on FACEBOOK**

# %%
#calculating total number of null values in patient profile
patient_profiles.isnull().sum()
# Out:
# Patient_ID               0
# Online_Follower          0
# LinkedIn_Shared          0
# Twitter_Shared           0
# Facebook_Shared          0
# Income                   0
# Education_Score          0
# Age                      0
# First_Interaction        0
# City_Type            23384
# Employer_Category    34793
# dtype: int64

# %%
city_t=pd.DataFrame(patient_profiles['City_Type'].dropna())
ct = city_t.loc[:,'City_Type']
ct
# Out:
# 1        H
# 2        D
# 3        D
# 4        H
# 8        F
#         ..
# 37617    I
# 37618    A
# 37624    E
# 37626    F
# 37630    H
# Name: City_Type, Length: 14249, dtype: object

# %%
city_count = pd.DataFrame(patient_profiles['City_Type'].dropna()).value_counts()
city_count
# Out:
# City_Type
# B            2662
# H            2517
# A            1729
# D            1704
# G            1352
# E            1217
# C            1216
# I            1036
# F             816
# dtype: int64

# %%
c={'A':1729,'B':2662,'C':1216,'D':1704,'E':1217,'F':816,'G':1352,'H':2517,'I':1036}
plt.bar(c.keys(),c.values())
plt.title("Patient's Cities")
plt.xlabel("City Type")
plt.ylabel("Count")
plt.show()

# %%
dd.sort_values()
age_count = pd.DataFrame(d_patient_profiles['Age']).value_counts().sort_values()
age_count
# Out:
# Age
# 80         1
# 31         2
# 30         2
# 62         3
# 64         4
# 66         4
# 78         5
# 63         6
# 65         6
# 32         7
# 61         7
# 60        10
# 59        13
# 68        14
# 67        15
# 57        16
# 33        17
# 77        18
# 58        21
# 56        25
# 76        32
# 55        35
# 69        36
# 54        40
# 34        42
# 75        43
# 53        53
# 35        66
# 52        66
# 70        71
# 51        76
# 50       102
# 36       109
# 49       127
# 48       140
# 74       172
# 71       175
# 37       186
# 47       189
# 73       199
# 46       214
# 72       218
# 38       219
# 45       240
# 44       293
# 39       299
# 40       321
# 42       336
# 43       359
# 41       361
# 0      32618
# dtype: int64

# %%
patient_profiles['Employer_Category'].dropna()
# Out:
# 0        Software Industry
# 1        Software Industry
# 2                     BFSI
# 3                Education
# 4                   Others
#                ...
# 37460           Technology
# 37468               Others
# 37527               Others
# 37545           Consulting
# 37548        Manufacturing
# Name: Employer_Category, Length: 2840, dtype: object

# %%
emp_count = pd.DataFrame(patient_profiles['Employer_Category']).dropna().value_counts().sort_values()
emp_count
# Out:
# Employer_Category
# Broadcasting          51
# Food                  56
# Real Estate           57
# Telecom               58
# Transport             65
# Health                88
# Retail                91
# Manufacturing        115
# BFSI                 167
# Education            188
# Software Industry    374
# Consulting           404
# Others               477
# Technology           649
# dtype: int64

# %%
emp_type = ['Broadcasting','Food','Real Estate','Telecom','Transport','Health','Retail','Manufacturing','BFSI','Education','Software Industry','Consulting','Others','Technology']
plt.figure(figsize=(16,6))
plt.bar(emp_type,emp_count)
plt.title("Patient's Occuation")
plt.xlabel("Employee Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
Second_Health_Camp_Attended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7819 entries, 0 to 7818
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      7819 non-null   int64
#  1   Health_Camp_ID  7819 non-null   int64
#  2   Health Score    7819 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 183.4 KB

# %%
First_Health_Camp_Attended['Donation'].value_counts().sort_values()
# Out:
# 330       1
# 220       1
# 190       1
# 280       1
# 180       2
# 210       2
# 250       2
# 170       6
# 150       8
# 160       8
# 140      13
# 130      18
# 120      24
# 110      30
# 100      51
# 90       74
# 80       91
# 70      194
# 60      283
# 50      473
# 40      760
# 30     1250
# 10     1316
# 20     1609
# Name: Donation, dtype: int64

# %%
plt.hist(First_Health_Camp_Attended['Donation'], bins=30,color='red')
plt.title("Range of Donation recieved during First Health Camp Attended")
plt.xlabel('Amount')
plt.ylabel('Persons')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.hist(First_Health_Camp_Attended['Health_Score'], bins=40,color='green')
plt.title("Health Score of People attended First Health Camp")
plt.xlabel('Health Score')
plt.ylabel('Persons')

plt.subplot(1,2,2)
new_var = Second_Health_Camp_Attended['Health Score']
plt.hist(new_var, bins=40,color='c')
plt.title("Health Score of People attended Second Health Camp")
plt.xlabel('Health Score')
plt.ylabel('Persons')

plt.show()

# %%
Train
# Out:
#        Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  \
# 0          489652            6578         10-Sep-05     4     0     0     0
# 1          507246            6578         18-Aug-05    45     5     0     0
# 2          523729            6534         29-Apr-06     0     0     0     0
# 3          524931            6535         07-Feb-04     0     0     0     0
# 4          521364            6529         28-Feb-06    15     1     0     0
# ...           ...             ...               ...   ...   ...   ...   ...
# 75273      500969            6539         03-Jan-05     0     0     0     0
# 75274      511952            6528         13-Feb-06     0     0     0     0
# 75275      521236            6554         24-May-05     0     0     0     0
# 75276      518817            6580         22-Dec-04     0     0     0     0
# 75277      511284            6555         08-Aug-05     0     0     0     0
#
#        Var5
# 0         2
# 1         7
# 2         0
# ...

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(Train)
scatter_matrix
# Out:
# <function pandas.plotting._misc.scatter_matrix(frame: 'DataFrame', alpha: 'float' = 0.5, figsize: 'tuple[float, float] | None' = None, ax: 'Axes | None' = None, grid: 'bool' = False, diagonal: 'str' = 'hist', marker: 'str' = '.', density_kwds=None, hist_kwds=None, range_padding: 'float' = 0.05, **kwargs) -> 'np.ndarray'>

# %%
def max_d():
    b=input("Do you Want to find the maximum donation from First Camp? Enter Y if Yes or Enter N if No !")
    if b == 'Y':
        print(max(First_Health_Camp_Attended["Donation"]))
    elif b== 'N':
        print('Thank You')

max_d()
# Out:
# 330

# %%
def total_donation():
    count=0
    for i in First_Health_Camp_Attended['Donation'].dropna():
        count=count+i
    return count
total_donation()
# Out:
# 202630

# %%
First_Health_Camp_Attended['Health_Score']
# Out:
# 0       0.439024
# 1       0.097561
# 2       0.048780
# 3       0.634146
# 4       0.024390
#           ...
# 6213    0.509804
# 6214    0.078431
# 6215    0.627451
# 6216    0.686275
# 6217    0.921569
# Name: Health_Score, Length: 6218, dtype: float64

# %%
Second_Health_Camp_Attended['Health Score']
# Out:
# 0       0.875136
# 1       0.755700
# 2       0.673181
# 3       0.722041
# 4       0.464712
#           ...
# 7814    0.103136
# 7815    0.507841
# 7816    0.627865
# 7817    0.252714
# 7818    0.691194
# Name: Health Score, Length: 7819, dtype: float64

# %%
#Average health score comparision between datasets
sum1=0
for i in First_Health_Camp_Attended['Health_Score']:
    sum1=sum1+i
avg_score1 = (sum1/6216)
print(avg_score1)
# Out:
# 0.5178341789879312

# %%
sum2=0
for j in Second_Health_Camp_Attended['Health Score']:
    sum2=sum2+j
avg_score2 = (sum2/7817)
print(avg_score2)
# Out:
# 0.5543199652553544

# %%
avrgs = [avg_score1,avg_score2]
avrgs_label = ['Average Health Score of First Health Camp','Average Health Score of Second Health Camp']
expl=[0,0.04]
cols=['orange','c']
plt.figure(figsize=(10,8))
plt.pie(avrgs, labels= avrgs_label, colors=cols,startangle=0,explode=expl,shadow=True,autopct='%1.0f%%')
plt.legend(title="Health Score of First and Second Health Camp",loc='lower right')
plt.title(label='Comparision of Health Score of First and Second Health Camp', fontsize = 20)
plt.show()

# %%
import scipy.stats
scipy.stats.pearsonr(First_Health_Camp_Attended['Health_Score'].head(6000),Second_Health_Camp_Attended['Health Score'].head(6000))
# Out:
# PearsonRResult(statistic=-0.0037784006722930063, pvalue=0.7698174236706282)
