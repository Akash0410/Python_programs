# %%
a = input("enter the string")
if len(a) ==5 and a == a[::-1]:
    print(True)
else:
    print(False)
# Out:
# True

# %%
# Importing urllib request module in the program  
import urllib.request  
# Using urlopen() function with url in it  
webUrl = urllib.request.urlopen('https://www.google.com/') 
print(webUrl)
# Out:
# KeyboardInterrupt

# %%
import pandas as pd
student_info = pd.read_csv('C:/Users/Akash Raj/Downloads/Student_Marks.csv')
student_info
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
student_info.dropna()
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.bar(student_info['number_courses'],student_info['time_study'])
plt.xlabel('Number of courses')
plt.ylabel('Spent time on Study')

plt.subplot(1,2,2)
plt.bar(student_info['Marks'], student_info['time_study'])
plt.xlabel('Marks Obtained')
plt.ylabel('Spent time on Study')

plt.show()

# %%
student_details = pd.read_csv('C:/Users/Akash Raj/Downloads/StudentsPerformance.csv')
print(student_details.to_string())
# Out:
#      gender race/ethnicity parental level of education         lunch test preparation course  math score  reading score  writing score
# 0    female        group B           bachelor's degree      standard                    none          72             72             74
# 1    female        group C                some college      standard               completed          69             90             88
# 2    female        group B             master's degree      standard                    none          90             95             93
# 3      male        group A          associate's degree  free/reduced                    none          47             57             44
# 4      male        group C                some college      standard                    none          76             78             75
# 5    female        group B          associate's degree      standard                    none          71             83             78
# ...

# %%
for i in student_details['math score']:
    if i<20:
        x=student_details['math score'].replace(i, 25)
        print(x.to_string())
# Out:
# 0       72
# 1       69
# 2       90
# 3       47
# 4       76
# 5       71
# 6       88
# 7       40
# 8       64
# 9       38
# 10      58
# 11      40
# 12      65
# 13      78
# 14      50
# 15      69
# 16      88
# 17      25
# 18      46
# 19      54
# 20      66
# 21      65
# 22      44
# 23      69
# 24      74
# 25      73
# 26      69
# 27      67
# 28      70
# 29      62
# 30      69
# 31      63
# 32      56
# 33      40
# 34      97
# 35      81
# 36      74
# 37      50
# 38      75
# 39      57
# 40      55
# 41      58
# 42      53
# 43      59
# 44      50
# 45      65
# 46      55
# 47      66
# 48      57
# 49      82
# 50      53
# 51      77
# 52      53
# 53      88
# 54      71
# 55      33
# 56      82
# 57      52
# 58      58
# 59       0
# 60      79
# 61      39
# 62      62
# 63      69
# 64      59
# 65      67
# 66      45
# 67      60
# 68      61
# 69      39
# 70      58
# 71      63
# 72      41
# 73      61
# 74      49
# 75      44
# ...

# %%
import pandas as pd
import tkinter as *

classwork = pd.read_csv('C:/Users/Akash Raj/Desktop/classwork.csv')
classwork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Content  5 non-null      object
# dtypes: object(1)
# memory usage: 168.0+ bytes

# %%
from numpy import NaN


classwork_type = pd.DataFrame(classwork['Content']).replace('python',NaN)
print(classwork_type.to_string())
# Out:
#   Content
# 0     100
# 1     200
# 2     NaN
# 3  300.12
# 4     400

# %%
classwork_dtype = pd.DataFrame(classwork_type).astype('float')
classwork_dtype
# Out:
#    Content
# 0   100.00
# 1   200.00
# 2      NaN
# 3   300.12
# 4   400.00

# %%
classwork1 = pd.read_csv('C:/Users/Akash Raj/Desktop/classwork1.csv')
classwork1_c1 = pd.DataFrame(classwork1['col 1'])
classwork1_c1
# Out:
#    col 1
# 0   1 4
# 1    1 2
# 2    2 3
# 3   3 4
# 4    4 7
# 5   5 11

# %%
import urllib.request  
# Using urlopen() function with url in it  
webUrl = urllib.request.urlopen('https://www.google.com/') 
webUrl

# %%
import matplotlib.pyplot as plt

value1=[84,77,20,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,25,35,32,96,99,3,90,95,34,27,55,100,15,71,11,37,21]
value3=[23,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]
value4=[59,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data = [value1,value2, value3, value4]
plt.boxplot(box_plot_data)
plt.show()

# %%
import matplotlib.pyplot as plt

value1=[84,77,20,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,25,35,32,96,99,3,90,95,34,27,55,100,15,71,11,37,21]
value3=[23,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]
value4=[59,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data = [value1,value2, value3, value4]
plt.boxplot(box_plot_data,patch_artist=True, labels=['subject1','subject2','subject3','subject4'])
plt.show()

# %%
value1=[84,77,20,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,25,35,32,96,99,3,90,95,34,27,55,100,15,71,11,37,21]
value3=[23,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]
value4=[59,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data = [value1,value2, value3, value4]
plt.boxplot(box_plot_data,notch='True',patch_artist=True, labels=['subject1','subject2','subject3','subject4'])
plt.show()

# %%
value1=[84,77,20,40,67,62,75,78,71,32,98,89,78,67,72,82,87]
value2=[62,5,91,25,35,32,96,99,3,90,95,34,27,55,100,11,37,21]
value3=[23,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]
value4=[59,73,73,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data = [value1,value2, value3, value4]
plt.boxplot(box_plot_data,patch_artist=True, labels=['subject1','subject2','subject3','subject4'])
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
student_data = pd.DataFrame({
'school_code': ['s001','s002','s003','s001','s002','s004'],
'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
'age': [12, 12, 13, 13, 14, 12],
'height': [173, 192, 186, 167, 151, 159],
'weight': [35, 32, 33, 30, 31, 32],
'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame:")
print(student_data)
print('\nSplit the said data on school_code wise:')
grouped = student_data.groupby(['school_code'])
print("Call school code 's001':")
print(grouped.get_group('s001'))
print("\nCall school code 's004':")
print(grouped.get_group('s004'))
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code wise:
# Call school code 's001':
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S1  street1
# S4  street1
#
# ...

# %% [markdown]
# <h4>Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\Akash Raj\Downloads\\alphabet_stock_data.csv")
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-09-30')
df['Date'] = pd.to_datetime(df['Date'])
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
df2 = df1.set_index('Date')
plt.figure(figsize=(5,5))
plt.suptitle('Stock prices of Alphabet Inc.,\n01-04-2020 to 30-09-2020', \
fontsize=18, color='black')
plt.xlabel("Date",fontsize=16, color='black')
plt.ylabel("$ price", fontsize=16, color='black')

df2['Close'].plot(color='green')
plt.show()

# %% [markdown]
# <h4>Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-4-30')
df['Date'] = pd.to_datetime(df['Date'])
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
df2 = df1.set_index('Date')
plt.figure(figsize=(6,6))
plt.suptitle('Trading Volume of Alphabet Inc. stock,\n01-04-2020 to 30-04-2020', fontsize=16, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("Trading Volume", fontsize=12, color='black')
df2['Volume'].plot(kind='bar')
plt.show()

# %% [markdown]
# <h4>Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-4-30')
df['Date'] = pd.to_datetime(df['Date'])
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
df2 = df1[['Date', 'Open', 'Close']]
df3 = df2.set_index('Date')
plt.figure(figsize=(30,20))
df3.plot.barh(stacked=True)
plt.suptitle('Opening/Closing stock prices Alphabet Inc.,\n01-04-2020 to 30-04-2020', fontsize=12, color='black')
plt.show()

# %%
import numpy as np
l= '1 2 3 4 5 6 7 8 9'
l1=[]
for i in l:
    if i != " ":
        l1.append(i)
print(l1)
arr = np.array(l1)
print(arr)
arr1= arr.reshape(3,3)
print(arr1)
'''n=9
for i in range(n):
    a=int(input())
    l1.append(a)

arr = np.array(l1)
arr1=np.reshape(arr,(3,3))
print(arr1)'''
# Out:
# 1 2 3 4 5 6 7 8 9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 24 in <cell line: 10>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=7'>8</a> arr = np.array(l)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=8'>9</a> print(arr)
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=9'>10</a> arr1= arr.reshape(3,3)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=10'>11</a> print(arr1)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=11'>12</a> '''n=9
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=12'>13</a> for i in range(n):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\Akash Raj\Downloads\weather.csv")

# %%
print(df.to_string())
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  RISK_MM RainTomorrow
# 0        8.0     24.3       0.0          3.4       6.3          NW           30.0         SW         NW           6.0            20           68           29       1019.7       1015.0         7         7     14.4     23.6        No      3.6          Yes
# 1       14.0     26.9       3.6          4.4       9.7         ENE           39.0          E          W           4.0            17           80           36       1012.4       1008.4         5         3     17.5     25.7       Yes      3.6          Yes
# ...

# %%
import pandas as pd
csv1 = pd.read_html('https://www.timeanddate.com/weather/india')
print(len(csv1))
# Out:
# 2
