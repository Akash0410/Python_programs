# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.0

# %%
df = pd.read_csv('C:/Users/Akash Raj/Downloads/data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.dropna(inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
df.dropna(inplace=False)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.dropna(inplace=0)
print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Untitled-10.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-10.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=0'>1</a> df.dropna(inplace=0)
#       <a href='vscode-notebook-cell:Untitled-10.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=1'>2</a> print(df.to_string())
#
# File c:\Users\Akash Raj\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# ...

# %%
df.fillna(130,inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df['Calories'].fillna(111, inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Out:
# 310.2

# %%
df = pd.read_csv('C:/Users/Akash Raj/Downloads/data.csv')
x= df['Calories'].median()
df['Calories'].fillna(x, inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     318.6
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(df.loc[7, 'Duration'] = 45)
# Out:
# 45

# %%
mydataset = {'cars':['BMW','Volvo','Ford'], 'passing':[3,7,2]}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passing
# 0    BMW        3
# 1  Volvo        7
# 2   Ford        2

# %%
mydataset = {'cars':['BMW','Volvo','Ford'], 'passing':[3,7,2]}
myvar = pd.Series(mydataset, index=['x', 'y', 'z'])
print(myvar)
# Out:
# x    NaN
# y    NaN
# z    NaN
# dtype: object

# %%
mydataset = {'cars':['BMW','Volvo','Ford'], 'passing':[3,7,2]}
myvar = pd.DataFrame(mydataset)
print(myvar)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('C:/Users/Akash Raj/Desktop/Marks.csv')
df1 = np.array(df.loc[:,'English'])
df2 = np.array(df.loc[:,'Names'])
plt.bar(df2,df1,width=0.6)
plt.xticks(rotation=60)
plt.figure(figsize=(20,20))
plt.show()
'''print(df2)
print(df1)'''
# Out:
# 'print(df2)\nprint(df1)'

# %%
import pyautogui
import time
time.sleep(4)
count=0
while count<=200:
    pyautogui.typewrite("Oki " 
    +str(count))
    pyautogui.press("enter")
    count+=1

# %%
import pandas as pd
a = pd.read_csv('C:/Users/Akash Raj/Downloads/netflix1.csv')
print(a)
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...
